# %% [markdown]
# <a href="https://colab.research.google.com/github/jubedoyag/MetNumUN2021II/blob/main/Lab5/group4SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# - (2x+1)(2x-1)(x-2)(x-4)(x-6) = 4 x^5 - 48 x^4 + 175 x^3 - 180 x^2 - 44 x + 48
#
# - (4 x^5 - 48 x^4 + 175 x^3 - 180 x^2 - 44 x + 48) / (x-2) = 4 x^4  - 40 x^3  + 95 x^2  + 10 x - 24

# %% [markdown]
# <img src="https://github.com/jubedoyag/MetNumUN2021II/blob/main/Lab5/images/imagen1polinomio.png?raw=true" /> <img src="https://github.com/jubedoyag/MetNumUN2021II/blob/main/Lab5/images/imagen2polinomio.png?raw=true" />

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = 4*x**5 - 48*x**4  + 175*x**3 - 180*x**2 - 44*x + 48

p, r = div(p,  x-2)

print(p)
print(r)

p, r = div(p,  x-4)

print(p)
print(r)

p, r = div(p,  x-6)

print(p)
print(r)

p, r = div(p,  2*x-1)

print(p)
print(r)
# Out:
# 4*x**4 - 40*x**3 + 95*x**2 + 10*x - 24
# 0
# 4*x**3 - 24*x**2 - x + 6
# 0
# 4*x**2 - 1
# 0
# 2*x + 1
# 0

# %%
p = 4*x**5 - 48*x**4  + 175*x**3 - 180*x**2 - 44*x + 48

p, r = div(p,  x-1)

print(p)
print(r)
# Out:
# 4*x**4 - 44*x**3 + 131*x**2 - 49*x - 93
# -45

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(4x\*\*5 - 48\*x\*\*4  + 175\*x\*\* 3 - 180\*x\*\* 2 - 44\*x + 48)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(4*x**5 - 48*x**4  + 175*x**3 - 180*x**2 - 44*x + 48)
# Out:
# (x - 6)*(x - 4)*(x - 2)*(2*x - 1)*(2*x + 1)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
# - 4x\*\*5 - 48\*x\*\*4  + 175\*x\*\* 3 - 180\*x\*\* 2 + 44\*x - 48 = 0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(4*x**5 - 48*x**4  + 175*x**3 - 180*x**2 - 44*x + 48, 0), x)
# Out:
# FiniteSet(-1/2, 1/2, 2, 4, 6)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi, sin
x = Symbol('x')
solveset(Eq(sin(2*x + pi/3), 0), x)
# Out:
# Union(ImageSet(Lambda(_n, _n*pi + pi/3), Integers), ImageSet(Lambda(_n, _n*pi + 5*pi/6), Integers))

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

def PolyGF2(p,mod):
    q,r = div(p,mod,x) #quotient and remainder polynomial division by modulus mod
    return q.as_poly(x,domain='GF(2)'), r.as_poly(x,domain='GF(2)')  #Z_2 ={0,1}

p = 4*x**5 - 48*x**4 + 175*x** 3 - 180*x** 2 + 44*x - 48
m = x - (4)
q,r = PolyGF2(p,m)
print("Quotient = ", q)
print("Residual= ", r)
# Out:
# Quotient =  Poly(x**2, x, modulus=2)
# Residual=  Poly(0, x, modulus=2)

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x*y*z

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/algorithms/master/SymPyLab/sympylabwolfram7.jpg" />

# %%
from sympy import *
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  
x = x1 + I*x2
y = y1 + I*y2
z = z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w=N(1/(pi + I), 20)
print('w=',w)
# Out:
# (x1 + I*x2)*(y1 + I*y2)*(z1 + I*z2)
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# w= 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  
x = 2*x1 + I*x2
y = 3*y1 + I*y2
z = 4*z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w=N(1/(pi + I), 20)
print('w=',w)
# Out:
# (2*x1 + I*x2)*(3*y1 + I*y2)*(4*z1 + I*z2)
# 24*x1*y1*z1 + 6*I*x1*y1*z2 + 8*I*x1*y2*z1 - 2*x1*y2*z2 + 12*I*x2*y1*z1 - 3*x2*y1*z2 - 4*x2*y2*z1 - I*x2*y2*z2
# 24*x1*y1*z1 + 6*I*x1*y1*z2 + 8*I*x1*y2*z1 - 2*x1*y2*z2 + 12*I*x2*y1*z1 - 3*x2*y1*z2 - 4*x2*y2*z1 - I*x2*y2*z2
# 24*x1*y1*z1 + 6*I*x1*y1*z2 + 8*I*x1*y2*z1 - 2*x1*y2*z2 + 12*I*x2*y1*z1 - 3*x2*y1*z2 - 4*x2*y2*z1 - I*x2*y2*z2
# w= 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average temperature in Bogota in September?
#
# <img src="https://raw.githubusercontent.com/gjhernandezp/algorithms/master/SymPyLab/sympylabwolfram6.jpg" />

# %% [markdown]
# - What is 37% of 245?
#
# ![WhatsApp Image 2021-11-02 at 10.08.45 AM.jpeg](data:image/jpeg;base64,...)
